# %% [markdown]
# <a href="https://colab.research.google.com/github/Asepharyana71/Belajar-MachineLearning/blob/main/part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install -y xubuntu-desktop
# Out:
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package libunity-gtk2-parser0:amd64.
# (Reading database ... 196342 files and directories currently installed.)
# Preparing to unpack .../000-libunity-gtk2-parser0_0.0.0+18.04.20171202-0ubuntu3_amd64.deb ...
# Unpacking libunity-gtk2-parser0:amd64 (0.0.0+18.04.20171202-0ubuntu3) ...
# Selecting previously unselected package libunity-gtk3-parser0:amd64.
# Preparing to unpack .../001-libunity-gtk3-parser0_0.0.0+18.04.20171202-0ubuntu3_amd64.deb ...
# Unpacking libunity-gtk3-parser0:amd64 (0.0.0+18.04.20171202-0ubuntu3) ...
# Selecting previously unselected package lightdm.
# Preparing to unpack .../002-lightdm_1.30.0-0ubuntu5_amd64.deb ...
# Unpacking lightdm (1.30.0-0ubuntu5) ...
# Selecting previously unselected package unity-gtk-module-common.
# Preparing to unpack .../003-unity-gtk-module-common_0.0.0+18.04.20171202-0ubuntu3_all.deb ...
# ...

# %%
import os
os.listdir('sample_data')
# Out:
# ['README.md',
#  'anscombe.json',
#  'mnist_test.csv',
#  'california_housing_train.csv',
#  'mnist_train_small.csv',
#  'california_housing_test.csv']

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
from sklearn.preprocessing import MinMaxScaler
data = [[12000000, 33], [35000000, 45], [4000000, 23], [6500000, 26], [9000000, 29]]
scaler = MinMaxScaler()
scaler.fit(data)
print(scaler.transform(data))
# Out:
# [[0.25806452 0.45454545]
#  [1.         1.        ]
#  [0.         0.        ]
#  [0.08064516 0.13636364]
#  [0.16129032 0.27272727]]
